# %%
import requests

print(requests.get("https://api.groq.com").status_code)
# Out:
# 200

# %%
import sys

print("sitecustomize" in sys.modules)
# Out:
# True

# %%
import os

print(os.environ.get("SSL_CERT_FILE"))
print(os.environ.get("REQUESTS_CA_BUNDLE"))
# Out:
# c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\certifi\cacert.pem
# c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\certifi\cacert.pem

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY= "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"

# %%
from openai import OpenAI
client = OpenAI()
 
response = client.responses.create(
    model="gpt-5.5",
    input="Write a one-sentence bedtime story about a unicorn."
)
 
print(response.output_text)
# Out:
# A sleepy little unicorn curled up on a cloud of moonlight, wished the stars sweet dreams, and drifted into a peaceful sleep beneath a silver rainbow.

# %%
print(response.output_text)
# Out:
# A sleepy little unicorn curled up on a cloud of moonlight, wished the stars sweet dreams, and drifted into a peaceful sleep beneath a silver rainbow.

# %%
import ssl_fix

# %%
from google import genai
from dotenv import load_dotenv
import os

load_dotenv()

client = genai.Client(
    api_key=os.getenv("GEMINI_API_KEY")
)

response = client.models.generate_content(
    model="gemini-flash-latest",
    contents="Explain how AI works in a few words"
)

print(response.text)
# Out:
# AI learns patterns from data to make smart decisions.

# %%
from google import genai
from dotenv import load_dotenv
load_dotenv()
client = genai.Client(api_key="GEMINI_API_KEY")

interaction = client.interactions.create(
    model="gemini-3-flash-preview",
    input="Explain how AI works in a few words"
    )
print(interaction.output_text)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\utils\unmarshal_json_response.py:57, in unmarshal_json_response(typ, http_res, body, validate)
#      56 try:
# ---> 57     return unmarshal_json(body, typ)
#      58 except Exception as e:
#
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\utils\serializers.py:132, in unmarshal_json(raw, typ)
#     131 def unmarshal_json(raw, typ: Any) -> Any:
# --> 132     return unmarshal(from_json(raw), typ, coerce_iterables=False)
#
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\utils\serializers.py:144, in unmarshal(val, typ, coerce_iterables)
#     138 unmarshaller = create_model(
#     139     "Unmarshaller",
#     140     body=(typ, ...),
#     141     __config__=ConfigDict(populate_by_name=True, arbitrary_types_allowed=True),
#     142 )
# --> 144 m = unmarshaller(body=val)
#     146 # pyright: ignore[reportAttributeAccessIssue]
#
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#
# ValidationError: 1 validation error for Unmarshaller
# body
#   Input should be a valid dictionary or instance of CreateInteractionClientErrorData [type=model_type, input_value=[{'error': {'code': 400, ...s a valid API key.'}]}}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.13/v/model_type
#
# The above exception was the direct cause of the following exception:
#
# ResponseValidationError                   Traceback (most recent call last)
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\interactions.py:489, in Interactions.create.<locals>._speakeasy_parse_response(http_res)
#     488 try:
# --> 489     response_data = unmarshal_json_response(
#     490         errors.CreateInteractionClientErrorData, http_res, http_res_text
#     491     )
#     492     raise errors.CreateInteractionClientError(
#     493         response_data, http_res, http_res_text
#     494     )
#
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\utils\unmarshal_json_response.py:61, in unmarshal_json_response(typ, http_res, body, validate)
#      60     return construct_unvalidated(json.loads(body), typ)
# ---> 61 raise errors.ResponseValidationError(
#      62     "Response validation failed",
#      63     http_res,
#      64     e,
#      65     body,
#      66 ) from e
#
# ResponseValidationError: Response validation failed: 1 validation error for Unmarshaller
# body
#   Input should be a valid dictionary or instance of CreateInteractionClientErrorData [type=model_type, input_value=[{'error': {'code': 400, ...s a valid API key.'}]}}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.13/v/model_type
#
# The above exception was the direct cause of the following exception:
#
# GenAiDefaultError                         Traceback (most recent call last)
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\interactions.py:563, in Interactions.create(self, request, api_version, extra_headers, extra_query, extra_body, timeout, **body_kwargs)
#     562 try:
# --> 563     return _speakeasy_parse_response(http_res)
#     564 except Exception as parse_exc_:
#
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\interactions.py:496, in Interactions.create.<locals>._speakeasy_parse_response(http_res)
#     495     except errors.ResponseValidationError as e:
# --> 496         raise errors.GenAiDefaultError(
#     497             "Error response body did not match expected schema",
#     498             http_res,
#     499             http_res_text,
#     500         ) from e
#     501 if utils.match_response(http_res, "5XX", "application/json"):
#
# GenAiDefaultError: Error response body did not match expected schema: Status 400 Content-Type "application/json; charset=UTF-8". Body: [{
#   "error": {
#     "code": 400,
#     "message": "API key not valid. Please pass a valid API key.",
#     "status": "INVALID_ARGUMENT",
#     "details": [
#       {
#         "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#         "reason": "API_KEY_INVALID",
#         "domain": "googleapis.com",
#         "metadata": {
#           "service": "generativelanguage.googleapis.com"
#         }
#       },
#       {
#         "@type": "type.googleapis.com/google.rpc.LocalizedMessage",
#         "locale": "en-US",
#         "message": "API key not valid. Please pass a valid API key."
#       }
#     ]
#   }
# }
# ]
#
# The above exception was the direct cause of the following exception:
#
# BadRequestError                           Traceback (most recent call last)
# Cell In[6], line 6
#       3 load_dotenv()
#       4 client = genai.Client(api_key="GEMINI_API_KEY")
# ----> 6 interaction = client.interactions.create(
#       7     model="gemini-3-flash-preview",
#       8     input="Explain how AI works in a few words"
#       9     )
#      10 print(interaction.output_text)
#
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\google_genai.py:271, in GeminiNextGenInteractions.create(self, request, api_version, extra_headers, extra_query, extra_body, timeout, **body)
#     269 stream = _optional_bool(body.get('stream'), default=False)
#     270 body = _normalize_create_body(body)
# --> 271 response = wrap_sdk_call(
#     272     super().create,
#     273     api_version=api_version,
#     274     **cast(Any, body),
#     275     extra_headers=extra_headers,
#     276     extra_query=extra_query,
#     277     extra_body=extra_body,
#     278     timeout=timeout,
#     279 )
#     280 if stream:
#     281     if is_stream(response):
#
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\lib\compat_errors.py:348, in wrap_sdk_call(fn, *args, **kwargs)
#     346 """Execute `fn(*args, **kwargs)`, translating known SDK exceptions."""
#     347 try:
# --> 348     return fn(*args, **kwargs)
#     349 except _WRAP_EXCEPTIONS as exc:
#     350     raise wrap_sdk_error(exc) from exc
#
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\interactions.py:565, in Interactions.create(self, request, api_version, extra_headers, extra_query, extra_body, timeout, **body_kwargs)
#     563     return _speakeasy_parse_response(http_res)
#     564 except Exception as parse_exc_:
# --> 565     response_helpers.raise_parse_error(
#     566         self.sdk_configuration.__dict__["_hooks"],
#     567         AfterParseErrorContext(_speakeasy_hook_ctx),
#     568         http_res,
#     569         parse_exc_,
#     570     )
#
# File c:\Users\VK131236\Downloads\AgenticAI\.venv\lib\site-packages\google\genai\_gaos\utils\response_helpers.py:92, in raise_parse_error(hooks, hook_ctx, response, exc)
#      90 if parse_error is exc:
#      91     raise exc.with_traceback(exc.__traceback__)
# ---> 92 raise parse_error from exc
#
# BadRequestError: Error code: 400 - [{'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}]

# %%
from langchain_ollama import ChatOllama

# %%
llm=ChatOllama(model="gpt-oss:120b-cloud")

# %%
response=llm.invoke("what is the stock price of Zensar today?")

# %%
response
# Out:
# AIMessage(content='I’m not able to pull live market data, so I can’t give you Zensar’s current stock price.  \n\n**How you can find it yourself**\n\n| Platform | Steps |\n|----------|-------|\n| **National Stock Exchange of India (NSE) website** | 1. Go to <https://www.nseindia.com>  <br>2. Enter “ZENSARTECH” (the NSE ticker for Zensar Technologies) in the search bar. <br>3. The quote page will show the latest price, change, volume, etc. |\n| **Bombay Stock Exchange (BSE) website** | 1. Visit <https://www.bseindia.com>  <br>2. Search for “Zensar Technologies” or the BSE code “531598”. <br>3. The stock‑quote page displays the live price. |\n| **Financial news portals** (Yahoo Finance, Google Finance, Moneycontrol, Bloomberg, Reuters) | 1. Search for “Zensar Technologies” or the ticker “ZENSARTECH.NS”. <br>2. The page refreshes automatically with the latest price. |\n| **Mobile/desktop brokerage apps** (Zerodha, Upstox, Groww, etc.) | 1. Log in to your account. <br>2. Look up the ticke
# ...

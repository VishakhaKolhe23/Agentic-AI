# %%
# from dotenv import load_dotenv
# from langchain_aws.chat_models import ChatBedrock
# import boto3
 
# load_dotenv()
 
# bedrock_client = boto3.client(
#     service_name='bedrock-runtime',
#     region_name='us-east-1'
# )
 
# llm = ChatBedrock(model_id="amazon.nova-micro-v1:0", client=bedrock_client)
 
# response = llm.invoke("Write a short poem about the beauty of nature.")
 
# print(response)
 #or below code

# %%
from dotenv import load_dotenv
from langchain_aws.chat_models import ChatBedrockConverse
 
load_dotenv() 
llm = ChatBedrockConverse(model_id="amazon.nova-lite-v1:0")
 
response = llm.invoke("Write a short poem about the beauty of nature.")
 
print(response.content)

#if langsmith erro come- click restart
# Out:
# Silent whispers through the trees,
# Golden rays kiss the dew,
# Nature's art in morning's breeze,
# A tapestry of colors, new.
#
# Blushing skies at twilight's grace,
# Stars like diamonds in the night,
# Peaceful rivers find their place,
# In nature's arms, we take flight.
#
# Earth's embrace, a timeless song,
# In every leaf, a story spun,
# Beauty pure, where we belong,
# Nature's wonder, never done.
